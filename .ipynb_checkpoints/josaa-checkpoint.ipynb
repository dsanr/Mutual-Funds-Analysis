# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('josaa seats.xlsx', index_col=0)

# %%
df
# Out:
#       Institute Code                                     Institute Name  \
# 0              101.0         Indian Institute of Technology Bhubaneswar
# 1              101.0         Indian Institute of Technology Bhubaneswar
# 2              101.0         Indian Institute of Technology Bhubaneswar
# 3              101.0         Indian Institute of Technology Bhubaneswar
# 4              101.0         Indian Institute of Technology Bhubaneswar
# ...              ...                                                ...
# 1968           428.0         Central University of Rajasthan, Rajasthan
# 1969           428.0         Central University of Rajasthan, Rajasthan
# 1970           430.0  National Institute of Food Technology Entrepre...
# 1971           430.0  National Institute of Food Technology Entrepre...
# 1972             NaN                                                NaN
#
#                                    Program Name State/All India Seats  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1973 entries, 0 to 1972
# Data columns (total 17 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Institute Code                                      1972 non-null   float64
#  1   Institute Name                                      1972 non-null   object
#  2   Program Name                                        1972 non-null   object
#  3   State/All India Seats                               1972 non-null   object
#  4   Seat Pool                                           1972 non-null   object
#  5   OPEN                                                1972 non-null   float64
#  6   OPEN-PwD                                            1972 non-null   float64
#  7   GEN-EWS                                             1972 non-null   float64
# ...

# %%
df.drop(1972, inplace=True)

# %%
df['Program-Total  Seat Capacity  Female Supernumerary'].str.split()
# Out:
# 0        [56, 2]
# 1        [56, 2]
# 2        [56, 3]
# 3        [56, 3]
# 4        [56, 6]
#           ...
# 1967     [15, 0]
# 1968     [15, 0]
# 1969     [15, 0]
# 1970    [169, 0]
# 1971    [169, 0]
# Name: Program-Total  Seat Capacity  Female Supernumerary, Length: 1972, dtype: object

# %%
total = df['Program-Total  Seat Capacity  Female Supernumerary'].str.split(expand=True)

# %%
df['Program-Total  Seat Capacity'] = total[0]

# %%
df['Program-Total  Female Supernumerary'] = total[1]

# %%
df.drop('Program-Total  Seat Capacity  Female Supernumerary', axis=1, inplace=True)

# %%
df['Total(includes Female Supernumerary)'] = df['Total(includes Female Supernumerary)'].str.split(n=1, expand=True)[0]

# %%
df.head()
# Out:
#    Institute Code                              Institute Name  \
# 0           101.0  Indian Institute of Technology Bhubaneswar
# 1           101.0  Indian Institute of Technology Bhubaneswar
# 2           101.0  Indian Institute of Technology Bhubaneswar
# 3           101.0  Indian Institute of Technology Bhubaneswar
# 4           101.0  Indian Institute of Technology Bhubaneswar
#
#                        Program Name State/All India Seats  \
# 0                 Civil Engineering             All India
# 1                 Civil Engineering             All India
# 2  Computer Science and Engineering             All India
# 3  Computer Science and Engineering             All India
# 4            Electrical Engineering             All India
#
#                                Seat Pool  OPEN  OPEN-PwD  GEN-EWS  \
# 0                         Gender-Neutral  21.0       1.0      2.0
# 1  Female-only (including Supernumerary)   5.0       0.0      1.0
# ...

# %%
cols = df.columns[-3:]

# %%
df[cols] = df[cols].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1972 entries, 0 to 1971
# Data columns (total 18 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Institute Code                        1972 non-null   float64
#  1   Institute Name                        1972 non-null   object
#  2   Program Name                          1972 non-null   object
#  3   State/All India Seats                 1972 non-null   object
#  4   Seat Pool                             1972 non-null   object
#  5   OPEN                                  1972 non-null   float64
#  6   OPEN-PwD                              1972 non-null   float64
#  7   GEN-EWS                               1972 non-null   float64
#  8   GEN-EWS-PwD                           1972 non-null   float64
#  9   SC                                    1972 non-null   float64
# ...

# %%
df.iloc[:, 5:-2].sum()
# Out:
# OPEN                                    19517.0
# OPEN-PwD                                  962.0
# GEN-EWS                                  2566.0
# GEN-EWS-PwD                               132.0
# SC                                       6392.0
# SC-PwD                                    343.0
# ST                                       3596.0
# ST-PwD                                    197.0
# OBC-NCL                                 10974.0
# OBC-NCL-PwD                               556.0
# Total(includes Female Supernumerary)    45235.0
# dtype: float64

# %%
df.iloc[:, 5:-3].sum()/(df['Program-Total  Seat Capacity'].sum()/2)
# Out:
# OPEN           0.450979
# OPEN-PwD       0.022229
# GEN-EWS        0.059292
# GEN-EWS-PwD    0.003050
# SC             0.147700
# SC-PwD         0.007926
# ST             0.083093
# ST-PwD         0.004552
# OBC-NCL        0.253576
# OBC-NCL-PwD    0.012847
# dtype: float64

# %%
((df['Program-Total  Female Supernumerary'].sum()/2) / df['Total(includes Female Supernumerary)'].sum())
# Out:
# 0.043285066872996575

# %%
(df.iloc[:, 5:-3].sum()/(df['Program-Total  Seat Capacity'].sum()/2))[1::2].sum()
# Out:
# 0.05060424705963907

# %%
df.columns
# Out:
# Index(['Institute Code', 'Institute Name', 'Program Name',
#        'State/All India Seats', 'Seat Pool', 'OPEN', 'OPEN-PwD', 'GEN-EWS',
#        'GEN-EWS-PwD', 'SC', 'SC-PwD', 'ST', 'ST-PwD', 'OBC-NCL', 'OBC-NCL-PwD',
#        'Total(includes Female Supernumerary)', 'Program-Total  Seat Capacity',
#        'Program-Total  Female Supernumerary'],
#       dtype='object')

# %%
df.groupby('Program Name').sum().sort_values('OPEN', ascending=False)
# Out:
#                                                     Institute Code    OPEN  \
# Program Name
# Computer Science and Engineering                           66298.0  3481.0
# Mechanical Engineering                                     47804.0  2613.0
# Electronics and Communication Engineering                  55992.0  2300.0
# Civil Engineering                                          42896.0  2005.0
# Electrical Engineering                                     29444.0  1673.0
# ...                                                            ...     ...
# Electrical Engineering and M.Tech Power Electro...           202.0     5.0
# Civil Engineering and M. Tech. in Structural En...           202.0     4.0
# Ceramic Engineering and M.Tech Industrial Ceramic            892.0     4.0
# BS in Mathematics                                            204.0     4.0
# Biotechnology                                                832.0     2.0
#
# ...

# %%
(df.groupby('Program Name').sum().sort_values('OPEN', ascending=False).iloc[:,-1] / df.groupby('Program Name').sum().sort_values('OPEN', ascending=False).iloc[:,-2]).sort_values(ascending=False)[:15]
# Out:
# Program Name
# Mechanical Engineering with M.Tech. in Manufacturing Engineering            0.272727
# Mechanical Engineering and M. Tech. in Mechanical System Design             0.272727
# Mechanical Engineering and M. Tech. in Thermal Science & Engineering        0.272727
# BS in Mathematics                                                           0.250000
# Mining Machinery Engineering                                                0.225000
# Environmental Science and Engineering                                       0.222222
# Electrical Engineering with M.Tech. in any of the listed specializations    0.217391
# Mechanical Engineering with M.Tech. in any of the listed specializations    0.196078
# Mineral Engineering                                                         0.193548
# Manufacturing Science and Engineering                                       0.193548
# Food Process Engineering                                                    0.193548
# ...

# %%
df.groupby('Institute Name').sum().sort_values('Total(includes Female Supernumerary)', ascending=False)
# Out:
#                                                     Institute Code   OPEN  \
# Institute Name
# Indian Institute of Technology Kharagpur                    8056.0  715.0
# Indian Institute of Technology (BHU) Varanasi               5800.0  530.0
# Indian Institute of Technology Roorkee                      3842.0  502.0
# Dr. B R Ambedkar National Institute of Technolo...          8844.0  436.0
# Indian Institute of Technology Bombay                       3264.0  516.0
# ...                                                            ...    ...
# Central University of Rajasthan, Rajasthan                  1712.0   14.0
# Indian Institute of Carpet Technology, Bhadohi               808.0   14.0
# Indian institute of information technology, Rai...           652.0   11.0
# University of Hyderabad                                      842.0    9.0
# Central institute of Technology Kokrajar, Assam             4250.0    9.0
#
# ...

# %%
IIT = df[df['Institute Name'].str.contains('Indian Institute of Technology')]

# %%
IIT.groupby('Institute Name').sum().sort_values('Total(includes Female Supernumerary)', ascending=False)
# Out:
#                                                Institute Code   OPEN  \
# Institute Name
# Indian Institute of Technology Kharagpur               8056.0  715.0
# Indian Institute of Technology (BHU) Varanasi          5800.0  530.0
# Indian Institute of Technology Roorkee                 3842.0  502.0
# Indian Institute of Technology Bombay                  3264.0  516.0
# Indian Institute of Technology Delhi                   2912.0  451.0
# Indian Institute of Technology Kanpur                  2834.0  449.0
# Indian Institute of Technology Madras                  3080.0  427.0
# Indian Institute of Technology (ISM) Dhanbad           3420.0  429.0
# Indian Institute of Technology Guwahati                2340.0  343.0
# Indian Institute of Technology Bhubaneswar             3030.0  182.0
# Indian Institute of Technology Patna                   1344.0  168.0
# Indian Institute of Technology Jodhpur                  864.0  138.0
# ...

# %%
NIT = df[df['Institute Name'].str.contains('National Institute of Technology')]

# %%
NIT.groupby('Institute Name').sum().sort_values('Total(includes Female Supernumerary)', ascending=False)
# Out:
#                                                     Institute Code   OPEN  \
# Institute Name
# Dr. B R Ambedkar National Institute of Technolo...          8844.0  436.0
# National Institute of Technology Calicut                    9064.0  477.0
# National Institute of Technology, Rourkela                 20516.0  478.0
# National Institute of Technology Raipur                    10368.0  470.0
# Maulana Azad National Institute of Technology B...          7308.0  453.0
# National Institute of Technology, Tiruchirappalli           9040.0  400.0
# National Institute of Technology, Warangal                 10944.0  387.0
# Sardar Vallabhbhai National Institute of Techno...          8244.0  422.0
# National Institute of Technology, Kurukshetra               6160.0  413.0
# National Institute of Technology Agartala                  10660.0  384.0
# Visvesvaraya National Institute of Technology, ...          8280.0  363.0
# ...

# %%
df.to_excel('josaa seats-1.xlsx')
